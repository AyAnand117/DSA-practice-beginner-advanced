# %%
# Rough Code
nums3 = [5,7,8,4,1,6,9,2,3]  
n = len(nums3)  
left = nums3[0:n//2]  
right = nums3[n//2:n]  
res = []  
for i,j in zip(left,right):  
    if i>=j:  
        res.append(j)  
        res.append(i)  
    else:  
        res.append(i)  
        res.append(j)  
print(res)  

# Before performing mergesort(nums)
# Lets try merging two sorted list first
arr1 = [1,2,3,4,5]   
arr2 = [1,6,7,8]  
def merge_arr(l,r):  
    res=[]  
    i,j=0,0  
    n,m=len(l),len(r)  
    while i<n and j<m:  
        if l[i]<=r[j]:  
            res.append(l[i])  
            i+=1  
        else:  
            res.append(r[j])  
            j+=1  
    if i<n:  
        while i<n:  
            res.append(l[i])  
            i+=1  
    if j<m:  
        while j<m:  
            res.append(r[j])  
            j+=1  
    return res  
merge_arr(arr1,arr2)
# Out:
# [1, 5, 6, 7, 8, 9, 2, 4]
# [1, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
#def swaping(arr):
#    n = len(arr) # 7
#    i,j = 1,(n-1) #i=1 , j=6
#    p = arr[0] #4
#    while i < n and j>0:  # i<7
#        if arr[i]>p and arr[j]<p: 
#            arr[i],arr[j] = arr[j],arr[i]
#        i+=1
#        j-=1
#    return arr

#swaping(array)

# %%
array = [5,7,8,4,1,11,6,9,2,3,23]

def sec_lar(arr):
    n = len(arr)
    i = 0
    largest = float('-inf')
    sec_largest = float('-inf')
    while i < n:
        if arr[i]>largest:
            largest = arr[i]
        if arr[i]>sec_largest and arr[i]!=largest:
            sec_largest = arr[i]
        i+=1
    return sec_largest
print(sec_lar(array))
# Fails terribly
# Out:
# 9

# %%
def rightrot(arr):
    i = 1
    lst = []
    n = len(arr)
    lst.append(arr[n-1])
    while 0<i<n: 
        lst.append(arr[i-1])
        i+=1
    return lst

# %%
arr = [1, 0, 2, 4, 3, 0, 0, 3, 5, 1]
n = len(arr)
for i in range(n-1,-1,-1):
    if arr[i] == 0:
        arr.pop(i)
m = len(arr)
j=0
while j< n-m:
    arr.append(0)
    j+=1
print(arr)

# %%
arr1 = [5,3,9,8,1,6,3,4,-10,71,-100,5,9,1]
n = len(arr1)
d = {}
for i in range(n):
    if arr1[i] not in d:
        d[arr1[i]] = i
d

# %%
text = input()
def palmoney(text):

# %%
t = 'abc'
len('abc')
d = {}
for k,v in enumerate(t)
# Out:
# 3

# %%
t = 'abccdedcba'
d = {}
a = []
m = 0
for i in t:
    d[i] = d.get(i,0)+1

for i in d:
    if d[i]%2==1:
        a.append(i)
        m+=1
if len(a)==0:
    m=0
else:
    m-=1
print(m)
print(d)
print(a)
# Out:
# 1
# {'a': 2, 'b': 2, 'c': 3, 'd': 2, 'e': 1}
# ['c', 'e']

# %%
t1 = 'abc'
d = {}
m =0
a = []
for i in t1:
    d[i] = d.get(i,0)+1
for i in d:
    if d[i]%2==1:
        a.append(d[i])
        m+=1
print(m)
# Out:
# 3

# %%
T = int(name)
for _ in range(T):
    N = int(input())      # Read the length of the string
    S = input()           # Read the actual string
    print(pal(S))
